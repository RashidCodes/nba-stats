# %%
from pandas import read_excel

test_df = read_excel("./reports/stats.xlsx")

# %%
test_df
# Out:
#      Rank                 PLAYER TEAM  AGE  GP  W  L   MIN  OFFRTG  DEFRTG  \
# 0       1             Alex Fudge  LAL   20   6  2  4   9.7    84.8   110.7
# 1       1         Christian Wood  LAL   28   6  2  4  17.0    87.2   111.0
# 2       1        Colin Castleton  LAL   23   6  2  4  11.0    91.5   109.4
# 3       1       D'Angelo Russell  LAL   27   6  2  4  20.8   116.6   102.7
# 4       1            D'Moi Hodge  LAL   24   6  2  4  10.5    88.8   108.5
# ..    ...                    ...  ...  ...  .. .. ..   ...     ...     ...
# 565   516               Rudy Gay  GSW   37   1  1  0   8.0   141.2    77.8
# 566   516       Ryan Arcidiacono  NYK   29   1  0  1  15.2   110.7   128.6
# 567   516           Tevian Jones  NOP   23   1  0  1   4.7    55.6   100.0
# 568   516  Vincent Valerio-Bodon  LAL   22   1  0  1   5.0    80.0   120.0
# 569   516             Vit Krejci  MIN   23   1  1  0   7.4    72.2    94.1
#
# ...
